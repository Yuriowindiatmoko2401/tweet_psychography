# %% [markdown]
# Data flow
#
# 1. Load data train n tes
# 2. Preparing function for clean text
# 3. Data exploratory to counting word distribution for each dataset
# 4. Set object n training data
# 5. Predict tes data
# 6. Counting accuracy based on  (the label of the i-th sample, i predicted label 1 if the i-th sample ,    if they are equal, I=1, otherwise, I=0

# %%
#import necessary basic library

import pandas as pd
import numpy as np

# %%
#Load data Train 

Train_txt_ = pd.read_csv('Sample Train 275 deui.txt', sep="\t", engine='python', header=None, skiprows=1, names=["Text","Kategori"])
Train_txt_
# Out:
#                                                   Text                Kategori
# 0    *GARA-GARA MENOLAK KHILAFAH, ALI ABDURRAZIQ DI...  Openness to experience
# 1    Antikecebong1 Mereka semua 1 gerbong lah.\n Nn...  Openness to experience
# 2    Wiranti mana suaranya stelah HTI menang d peng...  Openness to experience
# 3    Udah dijawab sama adminnya kmrn, lagian sekali...  Openness to experience
# 4    Goblokk ! Itu bukan bendera hti tp bendera keb...  Openness to experience
# 5     Penjahat2 khilafah memang bajingan statement2nya  Openness to experience
# 6    Sebodoh-bodohnya orang yang mau dikadalin Feli...  Openness to experience
# 7    Bila Di Indonesia Ada Tahrir HTI Di Iraq &amp;...  Openness to experience
# 8    HTI  ITU ORMAS YG ANTI PANCASILA DAN NEGARA2 I...  Openness to experience
# 9    Kalau sudah ngerti Perpu bahwa HTI sudah dilar...  Openness to experience
# 10   @Dennysiregar7 Siap bergabung untuk memerangi ...  Openness to experience
# ...

# %%
#Load data Tes 

Tes_txt_ = pd.read_csv('Sample Tes 25 deui.txt', sep="\t", engine='python', header=None, skiprows=1, names=["Text","Kategori"])
Tes_txt_
# Out:
#                                                  Text                Kategori
# 0   Usai Sholat Jumat, Umat Islam Madina Gelar Aks...            Agreebleness
# 1   Viral! GP Ansor Turunkan Bendera Ormas Terlara...            Agreebleness
# 2   Yenny wahid menjelaskan berdirinya khilafah da...            Agreebleness
# 3   Yenny Wahid Sebut Indonesia Tidak Mungkin Tera...            Agreebleness
# 4   Yusril Ihza Mahendra Menangkan HTI di Pengadil...            Agreebleness
# 5   Saat ini yg perlu di waspadai  kelompok-kelomp...       Conscientiousness
# 6                             Save umat with KHILAFAH       Conscientiousness
# 7                      Tanggungjawab sebagai khalifah       Conscientiousness
# 8   They're hating Felix, HTI. Sementara aku mendu...       Conscientiousness
# 9          Yang dibubarkan HTI koq Yang Pecah HANURA?       Conscientiousness
# 10  Saya bertanya pada teman-teman saya yang bangg...            Extraversion
# ...
